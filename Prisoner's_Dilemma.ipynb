# %% [markdown]
# <a href="https://colab.research.google.com/github/rajni0829/Python/blob/main/Prisoner's_Dilemma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pprint
import random

def settingGame():
    print("Enter the imprisonment years for confess and betray respectively\n")
    
    confessPrison_either = int(input("Enter the prison sentence for either confess: "))
    confessPrison_common = int(input("Enter the prison sentence for both of them confess: "))

    betrayPrison_either = int(input("Enter the betray sentence for either betray: "))
    betrayPrison_common = int(input("Enter the prison sentence for both of them betray: "))

    payoffMatrix = []
    actionSet = ['c', 'd']
    
    computerChoice = actionSet[random.randint(0, len(actionSet)-1)]
    
    
    return [[confessPrison_common, confessPrison_common],[confessPrison_either, betrayPrison_either],[betrayPrison_either, confessPrison_either], [betrayPrison_common, betrayPrison_common], computerChoice, payoffMatrix]
    # [int, int, int, int, str, list]
    

def perfectGame(array):
    userChoice = str(input("Confess(C) or Betray(B) ? "))
    print("\nHurray! It's a perfect game")
    
    if (userChoice == "C" or userChoice == "c") and (array[4] == "d"):
        tempList = [array[1][0], array[1][1]]
        array[len(array) - 1].append(tempList)
        print("Your choice:", userChoice, ", Computer's choice: ", array[4])
        print("Utility function for the current move")
        pprint.pprint(array[len(array) - 1])

    elif (userChoice == "D" or userChoice == "d") and (array[4] == "c"):
        tempList = [array[2][0], array[2][1]]
        array[len(array) - 1].append(tempList)
        print("Your choice:", userChoice, ", Computer's choice: ", array[4])
        print("Utility function for the current move")
        pprint.pprint(array[len(array) - 1])

    elif (userChoice == "C" or userChoice == "c") and (array[4] == "c"):
        tempList = [array[0][0], array[0][1]]
        array[len(array) - 1].append(tempList)
        print("Your choice:", userChoice, ", Computer's choice: ", array[4])
        print("Utility function for the current move")
        pprint.pprint(array[len(array) - 1])

    else:
        tempList = [array[3][0], array[3][1]]
        array[len(array) - 1].append(tempList)
        print("Your choice:", userChoice, "Computer's choice: ", array[4])
        print("Utility function for the current move")
        pprint.pprint(array[len(array) - 1])
      


def ambgiousGame(array):
    userChoice = str(input("Confess(C) or Betray(B) ? "))
    print("\nIt's an ambgious game")

    if (userChoice == "C" or userChoice == "c") and (array[4] == "d"):
        tempList = [array[1][0], array[1][1]]
        array[len(array) - 1].append(tempList)
        print("Your choice:", userChoice, ", Computer's choice:", array[4])
        print("Utility function for the current move")
        pprint.pprint(array[len(array) - 1])

    elif (userChoice == "D" or userChoice == "d") and (array[4] == "c"):
        tempList = [array[2][0], array[2][1]]
        array[len(array) - 1].append(tempList)
        print("Your choice:", userChoice, ", Computer's choice:", array[4])
        print("Utility function for the current move")
        pprint.pprint(array[len(array) - 1])

    elif (userChoice == "C" or userChoice == "c") and (array[4] == "c"):
        tempList = [array[0][0], array[0][1]]
        array[len(array) - 1].append(tempList)
        print("Your choice:", userChoice, ", Computer's choice:", array[4])
        print("Utility function for the current move")
        pprint.pprint(array[len(array) - 1])

    else:
        tempList = [array[3][0], array[3][1]]
        array[len(array) - 1].append(tempList)
        print("Your choice:", userChoice, ", Computer's choice:", array[4])
        pprint.pprint(array[len(array) - 1])
   


def wrongGamge(array): 
    userChoice = str(input("Confess(C) or Betray(B) ? "))
    print("\nOops! It's a wrong game")

    if (userChoice == "C" or userChoice == "c") and (array[3] == "d"):
        tempList = [array[1][0], array[1][1]]
        array[len(array) - 1].append(tempList)
        print("Your choice:", userChoice, "Computer's choice:", array[4])
        print("Utility function for the current move")
        pprint.pprint(array[len(array) - 1])

    elif (userChoice == "D" or userChoice == "d") and (array[4] == "c"):
        tempList = [array[2][0], array[2][1]]
        array[len(array) - 1].append(tempList)
        print("Your choice:", userChoice, "Computer's choice:", array[4])
        print("Utility function for the current move")
        pprint.pprint(array[len(array) - 1])

    elif (userChoice == "C" or userChoice == "c") and (array[4] == "c"):
        tempList = [array[0][0], array[0][1]]
        array[len(array) - 1].append(tempList)
        print("Your choice:", userChoice, ", Computer choice:", array[4])
        print("Utility function for the current move")
        pprint.pprint(array[len(array) - 1])

    else:
        tempList = [array[3][0], array[3][1]]
        array[len(array) - 1].append(tempList)
        print("Your choice:", userChoice, ", Computer choice:", array[4])
        pprint.pprint(array[len(array) - 1])



# Driver Code
def judge():
    array = settingGame()
    print("\nPayOff Matrix is : ",array[0:4])
    # pprint.pprint(array[0:4])
    confess_common = array[0]
    confess_betray = array[1]
    betray_confess = array[2];
    betray_common = array[3]
    
    #[
    #[confessPrison_common, confessPrison_common],[confessPrison_either, betrayPrison_either],[betrayPrison_either, confessPrison_either], 
    #[betrayPrison_common, betrayPrison_common], computerChoice, payoffMatrix]
    # ]


    if (confess_common[0] < betray_common[0]) and (confess_betray[0]  < betray_confess[0]) and (betray_confess[0] < betray_common[0]):
        perfectGame(array)

    elif confess_common[0] < betray_common[0]:                                               #( confess_betray[0]  < confess_common[0]):
       if (betray_confess[0] < betray_common[0] or confess_common[0] <= betray_common[0]):   #and (confess_common[0] - betray_common[0] < 4):
          ambgiousGame(array)

    else:
        wrongGamge(array)                                                                    #confess_common > betray_common and confess_betray[0]  > betray_confess[0]

    
judge()
# Out:
# Enter the imprisonment years for confess and betray respectively
#
# Enter the prison sentence for either confess: 5
# Enter the prison sentence for both of them confess: 7
# Enter the betray sentence for either betray: 9
# Enter the prison sentence for both of them betray: 11
#
# PayOff Matrix is :  [[7, 7], [5, 9], [9, 5], [11, 11]]
# Confess(C) or Betray(B) ? c
#
# Hurray! It's a perfect game
# Your choice: c , Computer's choice:  d
# Utility function for the current move
# [[5, 9]]
